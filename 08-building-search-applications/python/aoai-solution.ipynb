# %% [markdown]
# In order to run the following noteboooks, if you haven't done yet, you need to deploy a model that uses `text-embedding-ada-002` as base model and set the deployment name inside .env file as `AZURE_OPENAI_EMBEDDINGS_ENDPOINT`

# %%
import os
import pandas as pd
import numpy as np
from openai import AzureOpenAI
from dotenv import load_dotenv

load_dotenv()

client = AzureOpenAI(
  api_key=os.environ['AZURE_OPENAI_API_KEY'],  # this is also the default, it can be omitted
  api_version = "2023-05-15"
  )

model = os.environ['AZURE_OPENAI_EMBEDDINGS_DEPLOYMENT']

SIMILARITIES_RESULTS_THRESHOLD = 0.75
DATASET_NAME = "../embedding_index_3m.json"

# %% [markdown]
# Next, we are going to load the Embedding Index into a Pandas Dataframe. The Embedding Index is stored in a JSON file called `embedding_index_3m.json`. The Embedding Index contains the Embeddings for each of the YouTube transcripts up until late Oct 2023.

# %%
def load_dataset(source: str) -> pd.core.frame.DataFrame:
    # Load the video session index
    pd_vectors = pd.read_json(source)
    return pd_vectors.drop(columns=["text"], errors="ignore").fillna("")

# %% [markdown]
# Next, we are going to create a function called `get_videos` that will search the Embedding Index for the query. The function will return the top 5 videos that are most similar to the query. The function works as follows:
#
# 1. First, a copy of the Embedding Index is created.
# 2. Next, the Embedding for the query is calculated using the OpenAI Embedding API.
# 3. Then a new column is created in the Embedding Index called `similarity`. The `similarity` column contains the cosine similarity between the query Embedding and the Embedding for each video segment.
# 4. Next, the Embedding Index is filtered by the `similarity` column. The Embedding Index is filtered to only include videos that have a cosine similarity greater than or equal to 0.75.
# 5. Finally, the Embedding Index is sorted by the `similarity` column and the top 5 videos are returned.

# %%
def cosine_similarity(a, b):
    if len(a) > len(b):
        b = np.pad(b, (0, len(a) - len(b)), 'constant')
    elif len(b) > len(a):
        a = np.pad(a, (0, len(b) - len(a)), 'constant')
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def get_videos(
    query: str, dataset: pd.core.frame.DataFrame, rows: int
) -> pd.core.frame.DataFrame:
    # create a copy of the dataset
    video_vectors = dataset.copy()

    # get the embeddings for the query    
    query_embeddings = client.embeddings.create(input=query, model=model).data[0].embedding

    # create a new column with the calculated similarity for each row
    video_vectors["similarity"] = video_vectors["ada_v2"].apply(
        lambda x: cosine_similarity(np.array(query_embeddings), np.array(x))
    )

    # filter the videos by similarity
    mask = video_vectors["similarity"] >= SIMILARITIES_RESULTS_THRESHOLD
    video_vectors = video_vectors[mask].copy()

    # sort the videos by similarity
    video_vectors = video_vectors.sort_values(by="similarity", ascending=False).head(
        rows
    )

    # return the top rows
    return video_vectors.head(rows)

# %% [markdown]
# This function is very simple, it just prints out the results of the search query.

# %%
def display_results(videos: pd.core.frame.DataFrame, query: str):
    def _gen_yt_url(video_id: str, seconds: int) -> str:
        """convert time in format 00:00:00 to seconds"""
        return f"https://youtu.be/{video_id}?t={seconds}"

    print(f"\nVideos similar to '{query}':")
    for _, row in videos.iterrows():
        youtube_url = _gen_yt_url(row["videoId"], row["seconds"])
        print(f" - {row['title']}")
        print(f"   Summary: {' '.join(row['summary'].split()[:15])}...")
        print(f"   YouTube: {youtube_url}")
        print(f"   Similarity: {row['similarity']}")
        print(f"   Speakers: {row['speaker']}")

# %% [markdown]
# 1. First, the Embedding Index is loaded into a Pandas Dataframe.
# 2. Next, the user is prompted to enter a query.
# 3. Then the `get_videos` function is called to search the Embedding Index for the query.
# 4. Finally, the `display_results` function is called to display the results to the user.
# 5. The user is then prompted to enter another query. This process continues until the user enters `exit`.
#
# ![](../images/notebook-search.png?WT.mc_id=academic-105485-koreyst)
#
# You will be prompted to enter a query. Enter a query and press enter. The application will return a list of videos that are relevant to the query. The application will also return a link to the place in the video where the answer to the question is located.
#
# Here are some queries to try out:
#
# - What is Azure Machine Learning?
# - How do convolutional neural networks work?
# - What is a neural network?
# - Can I use Jupyter Notebooks with Azure Machine Learning?
# - What is ONNX?

# %%
pd_vectors = load_dataset(DATASET_NAME)

# get user query from imput
while True:
    query = input("Enter a query: ")
    if query == "exit":
        break
    videos = get_videos(query, pd_vectors, 5)
    display_results(videos, query)
# Out:
# Videos similar to 'What is a neural net?':
#  - Demystifying AI
#    Summary: The video discusses the concept of retraining neural networks for specific problem spaces. It explains...
#    YouTube: https://youtu.be/k-K3g4FKS_c?t=549
#    Similarity: 0.8343667489548782
#    Speakers: Micheleen Harris
#  - The Simplest Machine Learning
#    Summary: Neural networks are a type of design used in deep learning, which implements algorithms. Activation...
#    YouTube: https://youtu.be/kUV045QBWJg?t=183
#    Similarity: 0.8341518257287239
#    Speakers: Micheline Harris
#  - Demystifying AI
#    Summary: In the field of computer vision, researchers have made significant advancements in image recognition through...
#    YouTube: https://youtu.be/k-K3g4FKS_c?t=733
#    Similarity: 0.8324250579630628
#    Speakers: Micheleen Harris
#  - AI Applications Without a PhD
#    Summary: Fast.ai is a platform that aims to make deep learning accessible to everyone, regardless of...
#    YouTube: https://youtu.be/CijhTDXHdvs?t=184
#    Similarity: 0.8307942894272022
#    Speakers: Jeremy Howard
#  - Demystifying AI
#    Summary: Transfer learning was used in the Kaggle Data Science Bowl 2017 to determine if a...
#    YouTube: https://youtu.be/k-K3g4FKS_c?t=916
#    Similarity: 0.827843996939048
#    Speakers: Micheleen Harris
#
# Videos similar to 'Who is Homer Simpson?':
#  - Build Recap | Combining OpenAI models with the power of Azure
#    Summary: A video demonstrates how fine-tuning models can be used to train AI to speak like...
#    YouTube: https://youtu.be/K3x0VT4ncaE?t=552
#    Similarity: 0.783279619922318
#    Speakers: Chris Hoder
#
# Videos similar to 'What is an embedding?':
#  - Igniting Developer Innovation with Vector Search
#    Summary: The video discusses the concept of vector embeddings and their usefulness in searching for similar...
#    YouTube: https://youtu.be/otlYeBH9U6E?t=371
#    Similarity: 0.7964278476786468
#    Speakers: Liam, Cassie
#  - Meta LLama 2 Foundational Model with Prompt Flow
#    Summary: The video demonstrates how to use Azure Machine Learning and PromptFlow to create an AI...
#    YouTube: https://youtu.be/zFTnc8vbfVI?t=730
#    Similarity: 0.7905773009272208
#    Speakers: Cassie, Swati
#  - Author rich content in QnA Maker knowledge base and enable role based sharing
#    Summary: The video demonstrates the use of Rich Text Authoring in creating Q&A pairs for a...
#    YouTube: https://youtu.be/lB9klrdrqOk?t=183
#    Similarity: 0.7843631868318985
#    Speakers: Vishwac Sena Kannan, Neha Rajput
#  - Igniting Developer Innovation with Vector Search
#    Summary: The video discusses the use of vector databases, specifically Azure Cognitive Search, to efficiently search...
#    YouTube: https://youtu.be/otlYeBH9U6E?t=557
#    Similarity: 0.7812312771785942
#    Speakers: Liam, Cassie
#  - The Latest from Azure Video Indexer
#    Summary: Video Indexer is a powerful tool that allows companies to process and analyze large volumes...
#    YouTube: https://youtu.be/PICwbAfRWnk?t=182
#    Similarity: 0.7805880294585117
#    Speakers: David Dyckman, Yonit Hoffman, Cassie
#
# Videos similar to 'How to build an AI-powered chatbot':
#  - Use the Efficiency of Low-Code with the Extensibility to Azure to Design World-Class Chatbots
#    Summary: The video showcases how a digital assistant can be built using Power Virtual Agents. The...
#    YouTube: https://youtu.be/oJWJA-U4-m8?t=184
#    Similarity: 0.8705130195400751
#    Speakers: Pawan Taparia, Darren Jefford
#  - Taking a Look at Computer Vision’s Object Detection #TWiCognitive
#    Summary: In this video, the speaker demonstrates how to create a bot using QnA Maker. They...
#    YouTube: https://youtu.be/Fi-f9QMTx_Q?t=183
#    Similarity: 0.8647527852774488
#    Speakers: Noelle LaCharite
#  - Build a Bot in Minutes with QnA Maker #TWiCognitive
#    Summary: In this video, the speaker demonstrates how to create a bot using QnA Maker. They...
#    YouTube: https://youtu.be/MLlM-daiEO0?t=183
#    Similarity: 0.8647527852774488
#    Speakers: Noelle LaCharite
#  - Build a Bot in Minutes with QnA Maker #TWiCognitive
#    Summary: Noelle LaCharite demonstrates how to quickly and easily create a chatbot using QnA Maker. By...
#    YouTube: https://youtu.be/MLlM-daiEO0?t=0
#    Similarity: 0.8642549863870557
#    Speakers: Noelle LaCharite
#  - Conversational AI: Bot Building Tools
#    Summary: In this episode of The AI Show, Justin and Carlos discuss conversational AI tooling. They...
#    YouTube: https://youtu.be/AhIdpOMSXjM?t=0
#    Similarity: 0.8556181963637628
#    Speakers: Justin, Carlos
#
# Videos similar to '':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 # get user query from imput
#       4 while True:
# ----> 5     query = input("Enter a query: ")
#       6     if query == "exit":
#       7         break
#
# File /workspaces/generative-ai-for-beginners/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File /workspaces/generative-ai-for-beginners/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
